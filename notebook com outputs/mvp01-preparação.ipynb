# %% [markdown]
# ### Limpeza do ambiente de dados
#
# Nesta célula, o catálogo `mvp` é removido, caso exista, juntamente com todos os seus esquemas e tabelas associadas. Essa ação é utilizada para reinicializar o ambiente e evitar conflitos com estruturas previamente criadas.

# %%
# %sql
drop catalog if exists mvp cascade;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Criação do catálogo `mvp`
#
# Nesta célula, é criado o catálogo `mvp`, que servirá como contêiner lógico para organizar esquemas e tabelas do projeto no Databricks.

# %%
# %sql
create catalog mvp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Definição do catálogo ativo
#
# Nesta célula, o catálogo `mvp` é definido como o catálogo ativo da sessão, garantindo que as operações subsequentes sejam executadas dentro desse contexto.

# %%
# %sql
use catalog mvp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Remoção do schema `staging`
#
# Nesta célula, o schema `staging` é removido, caso exista, juntamente com todos os objetos associados, utilizando a opção `CASCADE`. Essa ação é aplicada para limpeza ou reestruturação do ambiente antes da criação de novos schemas.

# %%
# %sql
drop schema if exists staging cascade
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Criação do schema `staging`
#
# Nesta célula, é criado o schema `staging`, que será utilizado para armazenar dados intermediários ou temporários durante o processo de ingestão e transformação, servindo como etapa inicial do pipeline de dados.

# %%
# %sql
create schema staging
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Remoção do schema `bronze`
#
# Nesta célula, o schema `bronze` é removido, caso exista, juntamente com todas as tabelas e objetos associados, utilizando a opção `CASCADE`. Essa etapa é utilizada para limpeza ou recriação da camada Bronze do pipeline de dados.

# %%
# %sql
drop schema if exists bronze cascade
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Criação do schema `bronze`
#
# Nesta célula, é criado o schema `bronze`, destinado ao armazenamento dos dados brutos ingeridos, representando a camada inicial do pipeline de dados.

# %%
# %sql
create schema bronze
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Remoção do schema `silver`
#
# Nesta célula, o schema `silver` é removido, caso exista, juntamente com todas as tabelas e objetos associados, utilizando a opção `CASCADE`. Essa etapa é utilizada para limpar ou reconstruir a camada Silver do pipeline antes de novas transformações.

# %%
# %sql
drop schema if exists silver cascade
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Criação do schema `silver`
#
# Nesta célula, é criado o schema `silver`, que representa a camada intermediária do pipeline de dados, destinada ao armazenamento de dados tratados, padronizados e prontos para análises.

# %%
# %sql
create schema silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Remoção do schema `gold`
#
# Nesta célula, o schema `gold` é removido, caso exista, juntamente com todas as tabelas e objetos associados, utilizando a opção `CASCADE`. Essa etapa é utilizada para limpeza ou recriação da camada Gold do pipeline de dados.

# %%
# %sql
drop schema if exists gold cascade
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Criação do schema `gold`
#
# Nesta célula, é criado o schema `gold`, que representa a camada final do pipeline de dados, destinada ao armazenamento de dados consolidados e prontos para consumo analítico e visualização.

# %%
# %sql
create schema gold
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
