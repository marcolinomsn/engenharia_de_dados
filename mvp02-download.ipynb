# %%
spark.sql("USE CATALOG mvp")
spark.sql("USE SCHEMA staging")
# Out:
# DataFrame[]

# %%
# %sql
create volume dataset
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# Defina o caminho do volume
volume_path = '/Volumes/mvp/staging/dataset'

# Crie o volume se necessário
dbutils.fs.mkdirs(volume_path)

# URL do CSV no GitHub
csv_url = 'https://raw.githubusercontent.com/marcolinomsn/engenharia_de_dados/refs/heads/main/dataset/stations.csv'

# Caminho de destino no volume
csv_dest_path = f'{volume_path}/stations.csv'

# Baixe o arquivo CSV para o volume
dbutils.fs.cp(csv_url, csv_dest_path)

# Leia o CSV usando Spark
df = spark.read.csv(csv_dest_path, header=True, inferSchema=True)

display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>state</th><th>city_station</th><th>id_station</th><th>lat</th><th>lon</th><th>lvl</th><th>record_first</th><th>record_last</th></tr></thead><tbody><tr><td>CO</td><td>DF</td><td>BRASILIA</td><td>A001</td><td>-15,78944444</td><td>-47,92583332</td><td>1159,54</td><td>2000-05-07</td><td>2025-05-31</td></tr><tr><td>NE</td><td>BA</td><td>SALVADOR</td><td>A401</td><td>-13,01666666</td><td>-38,51666666</td><td>51,41</td><td>2000-05-13</td><td>2025-05-31</td></tr><tr><td>N</td><td>AM</td><td>MANAUS</td><td>A101</td><td>-3,10333333</td><td>-60,01638888</td><td>61,25</td><td>2000-05-09</td><td>2025-05-31</td></tr><tr><td>SE</td><td>RJ</td><td>ECOLOGIA AGRICOLA</td><td>A601</td><td>-22,8</td><td>-43,68333333</td><td>33</td><td>2000-05-07</td><td>2025-05-31</td></tr><tr><td>S</td><td>RS</td><td>PORTO ALEGRE</td><td>A801</td><td>-30,05</td><td>-51,16666666</td><td>46,97</td><td>2000-09-22</td><td>2025-05-31</td></tr><tr><td>CO</td><td>GO</td><td>GOIANIA</td><td>A002</td><td>-16,64277777</td><td>-49,21999999</td><td>770</td><td>2001-05-29</td><td>2025-05-19</td></tr><tr><td>CO</td><td>GO</td><td>MORRINHOS</td><td>A003</td><td>-17,71666667</td><td>-49,1</td><td>771,42</td><td>2001-05-25</td><td>2025-05-31</td></tr><tr><td>CO</td><td>MS</td><td>CAMPO GRANDE</td><td>A702</td><td>-20,45</td><td>-54,6</td><td>530</td><td>2001-09-10</td><td>2025-05-31</td></tr><tr><td>CO</td><td>MS</td><td>PONTA PORA</td><td>A703</td><td>-22,5525</td><td>-55,71638888</td><td>675</td><td>2001-09-07</td><td>2025-05-31</td></tr><tr><td>CO</td><td>MS</td><td>TRES LAGOAS</td><td>A704</td><td>-20,78999999</td><td>-51,71222222</td><td>313</td><td>2001-09-03</td><td>2025-05-31</td></tr><tr><td>NE</td><td>BA</td><td>BARREIRAS</td><td>A402</td><td>-12,15</td><td>-45,01666666</td><td>470,37</td><td>2001-12-20</td><td>2025-05-31</td></tr><tr><td>SE</td><td>SP</td><td>BAURU</td><td>A705</td><td>-22,35805555</td><td>-49,02888888</td
# Caminho de destino no volume
csv_dest_path = volume_path + '/weather_{}_filtered.csv'

# Baixe o arquivo CSV para o volume
for year in range(2000, 2026):
    print(f"Baixando o arquivo CSV do ano de {year} para o volume")
    dbutils.fs.cp(csv_url.format(year), csv_dest_path.format(year))

# Leia o ultimo CSV usando Spark
df = spark.read.csv(csv_dest_path.format(year), header=True, inferSchema=True)

display(df.limit(10))
# Out:
# Baixando o arquivo CSV do ano de 2000 para o volume
# Baixando o arquivo CSV do ano de 2001 para o volume
# Baixando o arquivo CSV do ano de 2002 para o volume
# Baixando o arquivo CSV do ano de 2003 para o volume
# Baixando o arquivo CSV do ano de 2004 para o volume
# Baixando o arquivo CSV do ano de 2005 para o volume
# Baixando o arquivo CSV do ano de 2006 para o volume
# Baixando o arquivo CSV do ano de 2007 para o volume
# Baixando o arquivo CSV do ano de 2008 para o volume
# Baixando o arquivo CSV do ano de 2009 para o volume
# Baixando o arquivo CSV do ano de 2010 para o volume
# Baixando o arquivo CSV do ano de 2011 para o volume
# Baixando o arquivo CSV do ano de 2012 para o volume
# Baixando o arquivo CSV do ano de 2013 para o volume
# Baixando o arquivo CSV do ano de 2014 para o volume
# Baixando o arquivo CSV do ano de 2015 para o volume
# Baixando o arquivo CSV do ano de 2016 para o volume
# Baixando o arquivo CSV do ano de 2017 para o volume
# Baixando o arquivo CSV do ano de 2018 para o volume
# Baixando o arquivo CSV do ano de 2019 para o volume
# Baixando o arquivo CSV do ano de 2020 para o volume
# Baixando o arquivo CSV do ano de 2021 para o volume
# Baixando o arquivo CSV do ano de 2022 para o volume
# Baixando o arquivo CSV do ano de 2023 para o volume
# Baixando o arquivo CSV do ano de 2024 para o volume
# Baixando o arquivo CSV do ano de 2025 para o volume
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DATA (YYYY-MM-DD)</th><th>Hora UTC</th><th>PRECIPITAÇÃO TOTAL, HORÁRIO (mm)</th><th>PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)</th><th>PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)</th><th>PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)</th><th>RADIACAO GLOBAL (KJ/m²)</th><th>TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)</th><th>TEMPERATURA DO PONTO DE ORVALHO (°C)</th><th>TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)</th><th>TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)</th><th>TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)</th><th>TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)</th><th>UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)</th><th>UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)</th><th>UMIDADE RELATIVA DO AR, HORARIA (%)</th><th>VENTO, DIREÇÃO HORARIA (gr) (° (gr))</th><th>VENTO, RAJADA MAXIMA (m/s)</th><th>VENTO, VELOCIDADE HORARIA (m/s)</th><th>ESTACAO</th></tr></thead><tbody><tr><td>2025-01-01</td><td>0000 UTC</td><td>0.0</td><td>886.1</td><td>886.1</td><td>885.5</td><td>null</td><td>20.8</td><td>19.5</td><td>20.9</td><td>20.7</td><td>19.5</td><td>19.2</td><td>92.0</td><td>90.0</td><td>92.0</td><td>8.0</td><td>3.6</td><td>1.8</td><td>A001</td></tr><tr><td>2025-01-01</td><td>